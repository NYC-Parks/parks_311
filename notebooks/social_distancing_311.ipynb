# %% [markdown]
# This notebook joins 311 social distancing complaints to Parks Properties using both spatial joins as well as fuzzy text matches using the 'description' field. Output is written to Google Sheets as number of complaints per park.
#
# Created by Julie Tsitron (julie.tsitron@parks.nyc.gov) in April 2020. Updated on 5/14/2021

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#imports" data-toc-modified-id="imports-1">imports</a></span></li><li><span><a href="#authentication" data-toc-modified-id="authentication-2">authentication</a></span></li><li><span><a href="#worksheets-created-for-output" data-toc-modified-id="worksheets-created-for-output-3">worksheets created for output</a></span></li><li><span><a href="#parks-data-(can-also-pull-this-from-Open-Data-)" data-toc-modified-id="parks-data-(can-also-pull-this-from-Open-Data-)-4">parks data (can also pull this from <strong><a href="https://data.cityofnewyork.us/Recreation/Parks-Properties/enfh-gkve" target="_blank">Open Data</a></strong> )</a></span></li><li><span><a href="#sample-311-data-(looking-at-social-distancing-complaints-in-this-example)-This-is-also-available-on--Open-Data" data-toc-modified-id="sample-311-data-(looking-at-social-distancing-complaints-in-this-example)-This-is-also-available-on--Open-Data-5">sample 311 data (looking at social distancing complaints in this example) This is also available on  <strong><a href="https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9" target="_blank">Open Data</a></strong></a></span><ul class="toc-item"><li><span><a href="#location-field" data-toc-modified-id="location-field-5.1">location field</a></span></li><li><span><a href="#look-at-previous-day's-complaints" data-toc-modified-id="look-at-previous-day's-complaints-5.2">look at previous day's complaints</a></span></li></ul></li><li><span><a href="#helper-functions-for-joining-311-complaints-to-parks" data-toc-modified-id="helper-functions-for-joining-311-complaints-to-parks-6">helper functions for joining 311 complaints to parks</a></span><ul class="toc-item"><li><span><a href="#spatial-joins" data-toc-modified-id="spatial-joins-6.1">spatial joins</a></span></li><li><span><a href="#'fuzzy'-text-match-joins" data-toc-modified-id="'fuzzy'-text-match-joins-6.2">'fuzzy' text match joins</a></span></li><li><span><a href="#concatenate-all-matches" data-toc-modified-id="concatenate-all-matches-6.3">concatenate all matches</a></span></li></ul></li><li><span><a href="#join-to-parks" data-toc-modified-id="join-to-parks-7">join to parks</a></span></li><li><span><a href="#cells-below-are-for-writing-output-to-google-sheet-(disregard)" data-toc-modified-id="cells-below-are-for-writing-output-to-google-sheet-(disregard)-8">cells below are for writing output to google sheet (disregard)</a></span></li></ul></div>

# %% [markdown]
# # imports

# %%
import pyodbc
import pandas as pd
import numpy as np
import gc
import datetime
import sys
import re
import geopandas as gpd
from geopandas import GeoDataFrame, GeoSeries
# import google.auth
from gspread import Client
from gspread_dataframe import set_with_dataframe

sys.path.append('../..')
from IPM_Shared_Code_public.Python.google_creds_functions_old import create_assertion_session
from IPM_Shared_Code_public.Python.geo_functions import read_geosql  ## this function allows us to read in spatial data directly from SQL Server into a GeoDataFrame
from IPM_Shared_Code_public.Python.utils import get_config

# %% [markdown]
# # authentication

# %%
config = get_config('c:\Projects\config.ini')

driver = config['srv']['driver']
server = config['srv']['server']
data_parks = config['srv']['data_parks']
dwh = config['db']['dwh']
cred_file = config['google']['path_to_file']

# %%
con = pyodbc.connect('Driver={' + driver + '};Server=' + server +
                     ';Database=' + dwh + ';Trusted_Connection=Yes;')
con_data_parks = pyodbc.connect('Driver={' + driver + '};Server=' +
                                data_parks + ';Database=' + dwh +
                                ';Trusted_Connection=Yes;')

# %%
scope = [
    'https://spreadsheets.google.com/feeds',
    'https://www.googleapis.com/auth/drive'
]

# %%
session = create_assertion_session(cred_file, scope)

# %%
gc = Client(None, session)

# %% [markdown]
# # worksheets created for output

# %%
wks = gc.open("Daily_311_SRs_at_Parks")
wks2 = gc.open("Daily 311 SR Hotspots at Parks")

# %% [markdown]
# # parks data (can also pull this from __[Open Data](https://data.cityofnewyork.us/Recreation/Parks-Properties/enfh-gkve)__ )

# %%
sql = 'select * from [DWH].[dbo].[TBL_PARKSGIS_PROPERTY]'
parks = read_geosql(sql, con_data_parks, geom_raw='Shape', geom_col='geometry')

# %% [markdown]
# # sample 311 data (looking at social distancing complaints in this example) This is also available on  __[Open Data](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9)__

# %%
sql_311='''
SELECT * FROM [DWH].[dbo].[tbl_311_social_distancing]
'''

# %%
SD_311 = pd.read_sql(sql_311, con)

# %%
SD_311.sort_values(by='open_datetime').tail()
# Out:
#              sr_num location_type  \
# 63941  311-06208474          Park
# 63942  311-06230854          Park
# 63943  311-06232321          Park
# 63945  311-06246159          Park
# 63944  311-06249675          Park
#
#                                         description_text       descriptor_1  \
# 63941  Men’s from the men shelter in the park play ar...  Social Distancing
# 63942  THERE ARE MULTIPLE PEOPLE RUNNING ON THE JOGGI...  Social Distancing
# 63943  Resident rpts basketball players at location a...  Social Distancing
# 63945  Hi. Im not sure where to file this but the bil...  Social Distancing
# 63944  These people are back at it. I just saw them b...  Social Distancing
#
#       agency       open_datetime     closed_datetime  \
# 63941    DPR 2021-05-09 08:34:07 2021-05-09 09:15:36
# 63942    DPR 2021-05-11 19:10:41 2021-05-11 19:21:07
# 63943    DPR 2021-05-11 22:06:03 2021-05-12 00:26:16
# 63945    DPR 2021-05-13 11:18:14 2021-05-13 14:03:43
# 63944    DPR 2021-05-13 17:09:40 2021-05-13 20:05:42
#
#                                               resolution  \
# 63941  Upon inspection the reported condition was not...
# 63942  No action was taken because the agency determi...
# 63943  NYC Parks has reviewed the reported condition ...
# 63945  Upon inspection the reported condition was not...
# 63944  NYC Parks couldn’t respond to your complaint b...
#
#       resolution_action_updated_dt  status  ...             street    zip  \
# 63941          2021-05-09 13:15:39  Closed  ...  BAISLEY POND PARK  11434
# 63942          2021-05-11 23:21:11  Closed  ...               None   None
# 63943          2021-05-12 04:26:19  Closed  ...          32 AVENUE  11354
# 63945          2021-05-13 18:03:47  Closed  ...   WEST  150 STREET  10039
# 63944          2021-05-14 01:48:21  Closed  ...   EAST  137 STREET  10454
#
#          borough      precinct patrolboroughcommand      park_facility_name  \
# 63941     QUEENS  Precinct 113         Queens South       Baisley Pond Park
# 63942   BROOKLYN   Unspecified          Unspecified           Prospect Park
# 63943     QUEENS  Precinct 109         Queens North              Bowne Park
# 63945  MANHATTAN   Precinct 32      Manhattan North             Unspecified
# 63944      BRONX   Precinct 40                Bronx  United We Stand Garden
#
#       park_borough        lat        lon  \
# 63941       QUEENS  40.676156 -73.785453
# 63942     BROOKLYN        NaN        NaN
# 63943       QUEENS  40.769851 -73.809152
# 63945    MANHATTAN  40.825535 -73.938470
# 63944        BRONX  40.804652 -73.914497
#
#                                                    shape
# 63941  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00b\xd...
# 63942                                               None
# 63943  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00r\xa...
# 63945  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00~\x8...
# 63944  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00b\xc...
#
# [5 rows x 23 columns]

# %% [markdown]
# ## location field

# %%
list(SD_311.sort_values(by='open_datetime').location_type.unique())
# Out:
# ['Park/Playground',
#  'Street/Sidewalk',
#  'Store/Commercial',
#  'Residential Building/House',
#  None,
#  'Park',
#  'Street/Curbside']

# %% [markdown]
# ## look at previous day's complaints

# %%
# Look at data from 2020 (more interesting):
today = datetime.datetime.today() - datetime.timedelta(days=365)

# %%
Year = today.year
Month = today.month
Day = today.day
Hour = 2
Min = 0
Sec = 0

# %%
dayOfInterest_st = pd.Timestamp(
    year=Year, month=Month, day=Day, hour=Hour, minute=Min,
    second=Sec) - datetime.timedelta(days=1)
dayOfInterest_end = pd.Timestamp(
    year=Year, month=Month, day=Day, hour=Hour, minute=Min,
    second=Sec) - datetime.timedelta(days=0)

# %%
SD_311_day = SD_311[(SD_311['open_datetime'] > dayOfInterest_st) & (
    SD_311['open_datetime'] <= dayOfInterest_end)].sort_values(
        by='open_datetime')

# %%
SD_311_day.head()
# Out:
#              sr_num     location_type  \
# 31939  311-02452843  Store/Commercial
# 32489  311-02452868   Street/Sidewalk
# 32487  311-02452915   Park/Playground
# 32303  311-02452954   Street/Sidewalk
# 31854  311-02452984   Street/Sidewalk
#
#                                         description_text       descriptor_1  \
# 31939  K c & k beauty supply \n234-01 Merrick Blvd \n...  Social Distancing
# 32489                       SOCIAL DISTANCING VIOLATION.  Social Distancing
# 32487  A pack of rare mix breed pit bulls are running...  Social Distancing
# 32303  Sidewalk fruit vendor not following social dis...  Social Distancing
# 31854  I was walking on Sterling place and Nostrand A...  Social Distancing
#
#       agency       open_datetime     closed_datetime  \
# 31939   NYPD 2020-05-13 02:13:28 2020-05-13 02:21:34
# 32489   NYPD 2020-05-13 02:24:03 2020-05-13 02:32:09
# 32487   NYPD 2020-05-13 02:26:46 2020-05-13 02:34:53
# 32303   NYPD 2020-05-13 02:48:51 2020-05-13 03:07:22
# 31854   NYPD 2020-05-13 03:12:05 2020-05-13 03:19:58
#
#                                               resolution  \
# 31939  The Police Department responded to the complai...
# 32489  The Police Department responded to the complai...
# 32487  The Police Department responded to the complai...
# 32303  The Police Department responded to the complai...
# 31854  The Police Department responded to the complai...
#
#       resolution_action_updated_dt  status  ...             street    zip  \
# 31939          2020-05-13 02:19:00  Closed  ...  MERRICK BOULEVARD  11422
# 32489          2020-05-13 02:32:00  Closed  ...          10 AVENUE  10019
# 32487          2020-05-13 02:34:00  Closed  ...  BAISLEY BOULEVARD  11434
# 32303          2020-05-13 03:07:00  Closed  ...       LENOX AVENUE  10037
# 31854          2020-05-13 03:19:00  Closed  ...    NOSTRAND AVENUE  11216
#
#          borough      precinct patrolboroughcommand park_facility_name  \
# 31939     QUEENS  Precinct 105         Queens South        Unspecified
# 32489  MANHATTAN   Precinct 18      Manhattan South        Unspecified
# 32487     QUEENS  Precinct 113         Queens South        Unspecified
# 32303  MANHATTAN   Precinct 32      Manhattan North        Unspecified
# 31854   BROOKLYN   Precinct 77       Brooklyn North        Unspecified
#
#       park_borough        lat        lon  \
# 31939       QUEENS  40.674450 -73.735917
# 32489    MANHATTAN  40.765933 -73.990877
# 32487       QUEENS  40.682430 -73.771061
# 32303    MANHATTAN  40.813106 -73.941577
# 31854     BROOKLYN  40.672530 -73.950251
#
#                                                    shape
# 31939  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\xdf...
# 32489  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x002\x1...
# 32487  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\x86...
# 32303  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\xcc...
# 31854  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00Du.A...
#
# [5 rows x 23 columns]

# %% [markdown]
# # helper functions for joining 311 complaints to parks

# %% [markdown]
# ## spatial joins

# %%
def get_gdf_from_df(df, lat_col, lon_col):
    return gpd.GeoDataFrame(df[~pd.isnull(df[lat_col])],
                            geometry=gpd.points_from_xy(
                                df[~pd.isnull(df[lat_col])][lon_col],
                                df[~pd.isnull(df[lat_col])][lat_col]),
                            crs=('epsg:4326'))

# %%
def buffer(gdf, buffer_radius, lat_col):
    geom_buffered = []
    for i in gdf.geometry:
        geom_buffered.append(i.buffer(buffer_radius))
    crs = 'epsg:2236'
    buffered_gdf = gpd.GeoDataFrame(gdf[~pd.isnull(gdf[lat_col])],
                                    crs=crs,
                                    geometry=geom_buffered)
    return buffered_gdf

# %%
def get_spatial_match(buffered_df, parks_df):
    return gpd.sjoin(buffered_df, parks_df, op='intersects')

# %%
def filter_spatial_match(spatial_match_df, loc_col, non_park_locs_list,
                         cols_to_keep_list):
    return spatial_match_df[~spatial_match_df[loc_col].
                            isin(non_park_locs_list)][cols_to_keep_list]

# %%
def get_missed_desc(df, spatial_match_filtered_df):
    missing_descriptions_list = []
    groups = df.groupby(loc_col).groups.keys()
    if 'Park/Playground' in groups:
        for i in df.groupby(loc_col).get_group(
                'Park/Playground')['description_text'].values:
            if i not in spatial_match_filtered_df.description_text.values:
                print(i)
                missing_descriptions_list.append(i)
    return missing_descriptions_list

# %% [markdown]
# ## 'fuzzy' text match joins

# %%
def match_park_text(park_df, parkname_col, pat1, pat2):
    return re.compile('({})'.format("|".join(
        list(park_df[(park_df[parkname_col] != pat1)
                     & (park_df[parkname_col] != pat2)]
             [parkname_col].str.lower().values))))

# %%
def match_any_text(pat):
    return re.compile(pat,re.UNICODE)

# %%
def find_parkname(row, descr_col, pat):
    if (re.search(pat, row[descr_col].lower())) != None:
        return re.search(pat, row[descr_col].lower()).groups()[0]

# %%
def get_missed_park_rows(gdf, desc_col, missed_desc_list, lat_col, loc_col):
    return gdf[
        (gdf[desc_col].isin(missed_desc_list))
        |
        ((pd.isnull(gdf[lat_col])) &
         (gdf[loc_col] == 'Park/Playground'))].copy()

# %% [markdown]
# ## concatenate all matches

# %%
def concat_spatial_and_text_matches(spatial_match_filtered_df,
                                    missed_park_rows_df):
    return pd.concat([
        spatial_match_filtered_df,
        missed_park_rows_df[~pd.isnull(missed_park_rows_df[parkname_col])]
    ],
                     sort=False)

# %% [markdown]
# # join to parks

# %%
sr_num_col = 'sr_num'
parkname_col = 'PropertyName'
desc_col = 'description_text'
lat_col = 'lat'
lon_col = 'lon'
loc_col = 'location_type'

cols_to_keep = [
    'sr_num', 'location_type', 'description_text', 'descriptor_1', 'agency',
    'open_datetime', 'closed_datetime', 'resolution',
    'resolution_action_updated_dt', 'status', 'bin', 'bbl', 'house_number',
    'street', 'zip', 'borough', 'precinct', 'patrolboroughcommand',
    'park_facility_name', 'park_borough', 'lat', 'lon', 'geometry',
    'index_right', 'PropertyName'
]

non_park_locs = [
    'Residential Building/House', 'Street/Sidewalk', 'Store/Commercial', ''
]

pat_park = match_park_text(parks, 'PropertyName', 'Park', 'Lot')

pat_mask = match_any_text(r'(mask|face covering)')

# %%
complaints_day_gdf = get_gdf_from_df(SD_311_day, lat_col, lon_col)

complaints_day_gdf= complaints_day_gdf.to_crs('epsg:2236')

# %%
complaints_day_gdf_buffered = buffer(complaints_day_gdf,100,'lat')

# %%
parks = parks.to_crs('epsg:2236')

# %%
complaints_day_gdf_buffered.head()
# Out:
#              sr_num     location_type  \
# 31939  311-02452843  Store/Commercial
# 32489  311-02452868   Street/Sidewalk
# 32487  311-02452915   Park/Playground
# 32303  311-02452954   Street/Sidewalk
# 31854  311-02452984   Street/Sidewalk
#
#                                         description_text       descriptor_1  \
# 31939  K c & k beauty supply \n234-01 Merrick Blvd \n...  Social Distancing
# 32489                       SOCIAL DISTANCING VIOLATION.  Social Distancing
# 32487  A pack of rare mix breed pit bulls are running...  Social Distancing
# 32303  Sidewalk fruit vendor not following social dis...  Social Distancing
# 31854  I was walking on Sterling place and Nostrand A...  Social Distancing
#
#       agency       open_datetime     closed_datetime  \
# 31939   NYPD 2020-05-13 02:13:28 2020-05-13 02:21:34
# 32489   NYPD 2020-05-13 02:24:03 2020-05-13 02:32:09
# 32487   NYPD 2020-05-13 02:26:46 2020-05-13 02:34:53
# 32303   NYPD 2020-05-13 02:48:51 2020-05-13 03:07:22
# 31854   NYPD 2020-05-13 03:12:05 2020-05-13 03:19:58
#
#                                               resolution  \
# 31939  The Police Department responded to the complai...
# 32489  The Police Department responded to the complai...
# 32487  The Police Department responded to the complai...
# 32303  The Police Department responded to the complai...
# 31854  The Police Department responded to the complai...
#
#       resolution_action_updated_dt  status  ...    zip    borough  \
# 31939          2020-05-13 02:19:00  Closed  ...  11422     QUEENS
# 32489          2020-05-13 02:32:00  Closed  ...  10019  MANHATTAN
# 32487          2020-05-13 02:34:00  Closed  ...  11434     QUEENS
# 32303          2020-05-13 03:07:00  Closed  ...  10037  MANHATTAN
# 31854          2020-05-13 03:19:00  Closed  ...  11216   BROOKLYN
#
#            precinct patrolboroughcommand park_facility_name park_borough  \
# 31939  Precinct 105         Queens South        Unspecified       QUEENS
# 32489   Precinct 18      Manhattan South        Unspecified    MANHATTAN
# 32487  Precinct 113         Queens South        Unspecified       QUEENS
# 32303   Precinct 32      Manhattan North        Unspecified    MANHATTAN
# 31854   Precinct 77       Brooklyn North        Unspecified     BROOKLYN
#
#              lat        lon  \
# 31939  40.674450 -73.735917
# 32489  40.765933 -73.990877
# 32487  40.682430 -73.771061
# 32303  40.813106 -73.941577
# 31854  40.672530 -73.950251
#
#                                                    shape  \
# 31939  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\xdf...
# 32489  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x002\x1...
# 32487  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\x86...
# 32303  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\xcc...
# 31854  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00Du.A...
#
#                                                 geometry
# 31939  POLYGON ((2671924.362 6028736.009, 2671923.881...
# 32489  POLYGON ((2598447.784 6056323.473, 2598447.302...
# 32487  POLYGON ((2661924.206 6030837.903, 2661923.724...
# 32303  POLYGON ((2610726.830 6074629.665, 2610726.349...
# 31854  POLYGON ((2612461.542 6023164.598, 2612461.060...
#
# [5 rows x 24 columns]

# %%
spatial_match = get_spatial_match(complaints_day_gdf_buffered,parks)

# %%
spatial_match.head()
# Out:
#              sr_num               location_type  \
# 31882  311-02453438  Residential Building/House
# 31947  311-02453533                        None
# 32494  311-02457190                        None
# 31875  311-02459398            Store/Commercial
# 31984  311-02453620             Street/Sidewalk
#
#                                         description_text       descriptor_1  \
# 31882  THIS SHELTER IS NOT PRACTICING SOCIAL DISTANCI...  Social Distancing
# 31947  The manager in the store and the employees hav...  Social Distancing
# 32494  THEY ARE NOT SOCIAL DISTANCING AT LOCATION IN ...  Social Distancing
# 31875  Young adults hanging out drinking, smoking, li...  Social Distancing
# 31984  14 unmasked crowd on park benches on Central P...  Social Distancing
#
#       agency       open_datetime     closed_datetime  \
# 31882   NYPD 2020-05-13 07:35:58 2020-05-13 08:05:02
# 31947   NYPD 2020-05-13 07:59:43 2020-05-13 08:07:47
# 32494   NYPD 2020-05-13 15:50:09 2020-05-13 16:31:26
# 31875   NYPD 2020-05-13 20:11:32 2020-05-13 20:34:48
# 31984   NYPD 2020-05-13 08:19:55 2020-05-13 08:38:33
#
#                                               resolution  \
# 31882  The Police Department responded to the complai...
# 31947  The Police Department responded to the complai...
# 32494  The Police Department responded to the complai...
# 31875  The Police Department responded to the complai...
# 31984  The Police Department responded to the complai...
#
#       resolution_action_updated_dt  status  ... Waterfront CreatedUser  \
# 31882          2020-05-13 08:04:00  Closed  ...         NO        None
# 31947          2020-05-13 08:07:00  Closed  ...         NO        None
# 32494          2020-05-13 16:31:00  Closed  ...         NO        None
# 31875          2020-05-13 20:34:00  Closed  ...         NO        None
# 31984          2020-05-13 08:38:00  Closed  ...         NO        None
#
#       CreatedDate       LastEditedUser               LastEditedDate  \
# 31882        None   NYCDPR\Alex.Butler  2021-01-29 18:02:05.0000000
# 31947        None       BEN.BLACKSHEAR  2020-07-21 16:53:04.0000000
# 32494        None       BEN.BLACKSHEAR  2020-07-21 16:53:04.0000000
# 31875        None       BEN.BLACKSHEAR  2020-07-21 16:53:04.0000000
# 31984        None  ANTONIOS.MICHELAKIS  2020-12-14 21:02:04.0000000
#
#           NYSAssembly NYSSenate USCongress  \
# 31882              86        33         15
# 31947          70, 71        30         13
# 32494          70, 71        30         13
# 31875          70, 71        30         13
# 31984  69, 68, 67, 75        29     10, 13
#
#                                    GlobalID GDB_GEOMATTR_DATA
# 31882  BE14A4EC-F5BA-4711-8A55-A3F87D671B17              None
# 31947  2468B9EF-4D12-4E2C-9D62-31AAAECF8B58              None
# 32494  2468B9EF-4D12-4E2C-9D62-31AAAECF8B58              None
# 31875  2468B9EF-4D12-4E2C-9D62-31AAAECF8B58              None
# 31984  9B51C8B1-5896-4A38-BAC1-FD5E6DFD83D6              None
#
# [5 rows x 63 columns]

# %%
len(spatial_match)
# Out:
# 132

# %%
spatial_match_filtered = filter_spatial_match(spatial_match, loc_col,
                                              non_park_locs, cols_to_keep)

# %%
len(spatial_match_filtered)
# Out:
# 73

# %%
missing_descriptions = get_missed_desc(SD_311_day, spatial_match_filtered)
# Out:
# A pack of rare mix breed pit bulls are running around the park ignoring social distancing guidelines. Leader of pack will respond to “Champ”.
# Guys from the block, bbq and hanging out at the park across the street from 1149 Morris ave.
# SOCCER TEAM  PLAYING IN THE PARK WITH 10 PEOPLE AND 2 ADULTS IN BIG BUSH PARK.
# overcrowding in park area, no social distancing
# WILLIAM F PASSANNANTA BALL FIELD
# EVERY DAY THERE IS A CROWD IN THE SCHOOL YARD WHICH HAS A LOCK ON IT AROUND 3:30PM. THEY ARE PLAYING AND NOT PRACTICING SOCIAL DISTANCING. THE FENCE IS LOCKED SO THEY ARE GETTING IN ANOTHER WAY
# A youth soccer team practices every day on the East River track (FDR/north of Houston). They take up a lot of space in the middle of the field and don't adhere to social distancing guidelines and endanger the people around them who are attempting to solo exercise. It's a large group of players, coaches, siblings, parents who get on the middle of the field and slowly take up more and more space.
# Charles Park is always crowded. Every time there is nice weather including today a lot of people go there. There are people playing baseball, tennis, and people in groups not wearing mask. This has been going on since the pandemic and shut down has begun. There has been no enforcement or action taken towards this. It’s absolutely ridiculous.
# ORGANIZED VOLLEYBALL GAME WITH TEN PLAYERS AND THE COACH.
# At school police officer Michael John buczek near precinct 34 a large group of kids are playing basketball on the basketball court. I counted about 20 kids with no social distancing.
# NO DISTANCING IN PARK
# Groups of people laying out in Gantry state park very close to one another and no masks
# SEVERAL DOZEN HASIDIC JEWS (ABOUT 80-100 PEOPLE. IN A PACKED ESPLANADE.  THEY ARE, WITH THEIR CHILDREN, WALKING AROUND, ALL THEM THEM HAVE DO NOT HAVE MASKS ON.  PRIOR COMPLAINTS FILES,  NYPD ARRIVES AND AFTER THEY LEAVE THE PEOPLE RETURN.
# 10 KIDS PLAYING BASKETBALL IN THE PARK AND THEY NOT PRACTICING SOCIAL DISTANCING
# Large groups of people who are not social distancing, not wearing masks on the 420 Kent Avenue waterfront between 420-490.
# Juniper park, many people just standing around socializing with no masks on.
# gathering in closed playground
# GROUP OF TEENS INSIDE THE PLAYGROUND
# The handball wall is fenced off but people are sneaking in and using the wall.
# There is a large gathering in an apartment complex in the parking lot, and they have no masks, and no social distancing. Loud noise and music.

# %%
missed_park_rows = get_missed_park_rows(complaints_day_gdf, desc_col,
                                        missing_descriptions, lat_col, loc_col)

# %%
missed_park_rows.head()
# Out:
#              sr_num    location_type  \
# 32487  311-02452915  Park/Playground
# 32133  311-02453700  Park/Playground
# 31976  311-02454070  Park/Playground
# 31975  311-02454278  Park/Playground
# 32279  311-02454483  Park/Playground
#
#                                         description_text       descriptor_1  \
# 32487  A pack of rare mix breed pit bulls are running...  Social Distancing
# 32133  Guys from the block, bbq and hanging out at th...  Social Distancing
# 31976  SOCCER TEAM  PLAYING IN THE PARK WITH 10 PEOPL...  Social Distancing
# 31975    overcrowding in park area, no social distancing  Social Distancing
# 32279  WILLIAM F PASSANNANTA BALL FIELD\nEVERY DAY TH...  Social Distancing
#
#       agency       open_datetime     closed_datetime  \
# 32487   NYPD 2020-05-13 02:26:46 2020-05-13 02:34:53
# 32133   NYPD 2020-05-13 08:40:36 2020-05-13 09:18:08
# 31976   NYPD 2020-05-13 09:39:57 2020-05-13 10:11:04
# 31975   NYPD 2020-05-13 10:15:16 2020-05-13 10:17:18
# 32279   NYPD 2020-05-13 10:36:40 2020-05-13 10:42:35
#
#                                               resolution  \
# 32487  The Police Department responded to the complai...
# 32133  The Police Department responded to the complai...
# 31976  The Police Department responded to the complai...
# 31975  The Police Department responded to the complai...
# 32279  The Police Department responded to the complai...
#
#       resolution_action_updated_dt  status  ...    zip    borough  \
# 32487          2020-05-13 02:34:00  Closed  ...  11434     QUEENS
# 32133          2020-05-13 09:18:00  Closed  ...  10456      BRONX
# 31976          2020-05-13 10:11:00  Closed  ...  11377     QUEENS
# 31975          2020-05-13 10:17:00  Closed  ...  10014  MANHATTAN
# 32279          2020-05-13 10:41:00  Closed  ...  10012  MANHATTAN
#
#            precinct patrolboroughcommand park_facility_name park_borough  \
# 32487  Precinct 113         Queens South        Unspecified       QUEENS
# 32133   Precinct 44                Bronx        Unspecified        BRONX
# 31976  Precinct 108         Queens North        Unspecified       QUEENS
# 31975   Unspecified          Unspecified        Unspecified    MANHATTAN
# 32279    Precinct 6      Manhattan South        Unspecified    MANHATTAN
#
#              lat        lon  \
# 32487  40.682430 -73.771061
# 32133  40.832143 -73.914748
# 31976  40.740623 -73.897752
# 31975  40.729170 -74.010676
# 32279  40.727749 -74.001551
#
#                                                    shape  \
# 32487  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\x86...
# 32133  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\xc4...
# 31976  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\xd0...
# 31975  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00V\xf...
# 32279  b'\xd7\x08\x00\x00\x01\x0c\x00\x00\x00\x00\x18...
#
#                               geometry
# 32487  POINT (2661824.206 6030837.903)
# 32133  POINT (2617497.162 6082175.677)
# 31976  POINT (2624922.064 6049179.293)
# 31975  POINT (2593930.689 6042475.401)
# 32279  POINT (2596503.872 6042159.688)
#
# [5 rows x 24 columns]

# %%
len(missed_park_rows)
# Out:
# 19

# %%
if not missed_park_rows.empty:
    missed_park_rows[parkname_col] = missed_park_rows.apply(
        lambda row: find_parkname(row, desc_col, pat_park), axis=1)

# %%
if not missed_park_rows.empty:
    all_matches = concat_spatial_and_text_matches(
        spatial_match_filtered, missed_park_rows)
else:
    all_matches = spatial_match_filtered.copy()## This is the full list

# %%
counts = all_matches.groupby(parkname_col).count()[[sr_num_col]].sort_values(
    by=sr_num_col, ascending=False)

hotspots = counts[counts[sr_num_col] > 1].copy()

hotspots.rename(columns={sr_num_col: 'Social Distancing 311 SRs'},
                inplace=True)

# %%
counts
# Out:
#                                      sr_num
# PropertyName
# Central Park                              4
# Van Cortlandt Park                        3
# Broadway Malls                            3
# Adam Clayton Powell Jr. Malls             2
# Maria Hernandez Park                      2
# McKinley Park                             2
# Isham Park                                2
# Inwood Hill Park                          2
# Riverside Park                            2
# Prospect Park                             2
# St. Mark's Playground                     2
# William F. Passannante Ballfield          2
# Tompkins Square Park                      2
# Siempre Verde Garden                      1
# Marine Park                               1
# McCarren Park                             1
# Trygve Lie Plaza                          1
# Middle Village Playground                 1
# Thomas Jefferson Park                     1
# Muller Triangle                           1
# Nathan Straus Playground                  1
# North Pacific Playground                  1
# Parade Ground                             1
# Peter's Field                             1
# Phil "Scooter" Rizzuto Park               1
# Macombs Dam Park                          1
# Quaker Parrot Park at the Dust Bowl       1
# Tall Oak Playground                       1
# Shore Park and Parkway                    1
# Madison Square Park                       1
# Kissena Corridor Park                     1
# Kissena Park                              1
# Federoff Triangle                         1
# Arden Woods                               1
# Asser Levy Park                           1
# Augustus St. Gaudens Playground           1
# Bay Terrace Playground                    1
# Big Bush Playground                       1
# Bronx River Parkway                       1
# Carl Schurz Park                          1
# Clement Clarke Moore Park                 1
# Clove Lakes Park                          1
# Cross Island Parkway                      1
# Fort Tryon Park                           1
# Aqueduct Walk                             1
# Frank Principe Park                       1
# Glendale Veterans Triangle                1
# Gorman Playground                         1
# Henry Hudson Park                         1
# Hoyt Playground                           1
# Hunter's Point South Park                 1
# Jaime Campiz Playground                   1
# James Burke Ballfield                     1
# Jennifer's Playground                     1
# Joan Of Arc Park                          1
# Willowbrook Parkway                       1

# %%
hotspots
# Out:
#                                   Social Distancing 311 SRs
# PropertyName
# Central Park                                              4
# Van Cortlandt Park                                        3
# Broadway Malls                                            3
# Adam Clayton Powell Jr. Malls                             2
# Maria Hernandez Park                                      2
# McKinley Park                                             2
# Isham Park                                                2
# Inwood Hill Park                                          2
# Riverside Park                                            2
# Prospect Park                                             2
# St. Mark's Playground                                     2
# William F. Passannante Ballfield                          2
# Tompkins Square Park                                      2

# %%
hotspots = pd.merge(
    hotspots.reset_index(),
    all_matches[all_matches[parkname_col].isin(hotspots.index.values)][[
        'PropertyName',
        'precinct',
        'patrolboroughcommand',
        'sr_num',
        'open_datetime',
    ]],
    left_on='PropertyName',
    right_on='PropertyName').sort_values(
        by=['Social Distancing 311 SRs', 'PropertyName', 'open_datetime'],
        ascending=False).set_index('Social Distancing 311 SRs')

# %%
hotspots
# Out:
#                                                PropertyName     precinct  \
# Social Distancing 311 SRs
# 4                                              Central Park  Precinct 24
# 4                                              Central Park  Precinct 22
# 4                                              Central Park  Precinct 22
# 4                                              Central Park  Precinct 22
# 3                                        Van Cortlandt Park  Precinct 50
# 3                                        Van Cortlandt Park  Precinct 50
# 3                                        Van Cortlandt Park  Precinct 50
# 3                                            Broadway Malls  Precinct 30
# 3                                            Broadway Malls  Precinct 24
# 3                                            Broadway Malls  Precinct 24
# 2                          William F. Passannante Ballfield   Precinct 6
# 2                          William F. Passannante Ballfield   Precinct 1
# 2                                      Tompkins Square Park   Precinct 9
# 2                                      Tompkins Square Park   Precinct 9
# 2                                     St. Mark's Playground  Precinct 77
# 2                                     St. Mark's Playground  Precinct 77
# 2                                            Riverside Park  Precinct 24
# 2                                            Riverside Park  Precinct 24
# 2                                             Prospect Park  Precinct 78
# 2                                             Prospect Park  Precinct 78
# 2                                             McKinley Park  Precinct 68
# 2                                             McKinley Park  Precinct 68
# 2                                      Maria Hernandez Park  Precinct 83
# 2                                      Maria Hernandez Park  Precinct 83
# 2                                                Isham Park  Precinct 34
# 2                                                Isham Park  Precinct 34
# 2                                          Inwood Hill Park  Precinct 34
# 2                                          Inwood Hill Park  Precinct 34
# 2                             Adam Clayton Powell Jr. Malls  Precinct 28
# 2                             Adam Clayton Powell Jr. Malls  Precinct 32
#
#                           patrolboroughcommand        sr_num  \
# Social Distancing 311 SRs
# 4                              Manhattan North  311-02460672
# 4                              Manhattan North  311-02460301
# 4                              Manhattan North  311-02458073
# 4                              Manhattan North  311-02457177
# 3                                        Bronx  311-02458779
# 3                                        Bronx  311-02458429
# 3                                        Bronx  311-02456109
# 3                              Manhattan North  311-02457841
# 3                              Manhattan North  311-02454456
# 3                              Manhattan North  311-02454456
# 2                              Manhattan South  311-02458828
# 2                              Manhattan South  311-02457361
# 2                              Manhattan South  311-02459658
# 2                              Manhattan South  311-02458093
# 2                               Brooklyn North  311-02457923
# 2                               Brooklyn North  311-02457366
# 2                              Manhattan North  311-02460005
# 2                              Manhattan North  311-02458045
# 2                               Brooklyn South  311-02457721
# 2                               Brooklyn South  311-02456375
# 2                               Brooklyn South  311-02458247
# 2                               Brooklyn South  311-02458019
# 2                               Brooklyn North  311-02459149
# 2                               Brooklyn North  311-02458901
# 2                              Manhattan North  311-02458126
# 2                              Manhattan North  311-02457627
# 2                              Manhattan North  311-02457627
# 2                              Manhattan North  311-02457597
# 2                              Manhattan North  311-02457190
# 2                              Manhattan North  311-02453533
#
#                                 open_datetime
# Social Distancing 311 SRs
# 4                         2020-05-13 22:54:12
# 4                         2020-05-13 22:09:18
# 4                         2020-05-13 17:34:20
# 4                         2020-05-13 15:47:39
# 3                         2020-05-13 18:56:13
# 3                         2020-05-13 18:19:44
# 3                         2020-05-13 13:49:52
# 3                         2020-05-13 17:01:20
# 3                         2020-05-13 10:29:40
# 3                         2020-05-13 10:29:40
# 2                         2020-05-13 19:03:45
# 2                         2020-05-13 16:08:18
# 2                         2020-05-13 20:36:26
# 2                         2020-05-13 17:35:27
# 2                         2020-05-13 17:16:23
# 2                         2020-05-13 16:10:52
# 2                         2020-05-13 21:27:50
# 2                         2020-05-13 17:27:46
# 2                         2020-05-13 16:49:24
# 2                         2020-05-13 14:19:09
# 2                         2020-05-13 17:53:04
# 2                         2020-05-13 17:28:24
# 2                         2020-05-13 19:37:36
# 2                         2020-05-13 19:03:51
# 2                         2020-05-13 17:40:47
# 2                         2020-05-13 16:37:47
# 2                         2020-05-13 16:37:47
# 2                         2020-05-13 16:37:35
# 2                         2020-05-13 15:50:09
# 2                         2020-05-13 07:59:43

# %% [markdown]
# # cells below are for writing output to google sheet (disregard)

# %%
todays_date = today - datetime.timedelta(days=1)

# %%
wks.add_worksheet(
    'all matches ' + str(todays_date.date()),
    len(
        all_matches.sort_values(by='open_datetime').drop(
            ['index_right', 'shape'], axis=1, errors='ignore')) + 1,
    len(
        all_matches.sort_values(by='open_datetime').drop(
            ['index_right', 'shape'], axis=1, errors='ignore').columns.values))

# %%
wks2.add_worksheet(
    'hotspots '+str(todays_date.date()),
    len(hotspots)+1,
    len(hotspots.reset_index().columns.values));

# %%
Sheet1 = wks.sheet1

# %%
hotspots_sheet = wks2.sheet1

# %%
wks.del_worksheet(Sheet1);

# %%
wks2.del_worksheet(hotspots_sheet);

# %%
# set_with_dataframe(
#     wks.sheet1,
#     all_matches.sort_values(by='open_datetime').drop(['index_right'],
#                                                      axis=1))

# %%
set_with_dataframe(
    wks.sheet1,
    all_matches.sort_values(by='open_datetime').drop(['index_right', 'shape'],
                                                     axis=1,errors='ignore'))

# %%
all_matches

# %%
set_with_dataframe(wks2.sheet1, hotspots.reset_index())

# %%
all_matches.sort_values(by='open_datetime')
